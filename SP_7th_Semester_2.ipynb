# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourove-331/Code-from-uri/blob/main/SP_7th_Semester_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Import pandas and seaborn module...

# %%
import pandas as pd
import seaborn as sms

# %% [markdown]
# 2. read the csv file. Encoding with 'latin-1' because 'utf-8' is failed to convert this csv file. 'ISO-8859-1' also have the ability to decode that file...

# %%
data_set = pd.read_csv('/content/drive/MyDrive/SP_7th_Project_2/SP.csv', encoding='latin-1')
# data_set = pd.read_csv('/content/drive/MyDrive/SP_7th_Project_2/SP.csv', encoding="ISO-8859-1")

# %% [markdown]
# 3. Show full data set of FIFA football player info...

# %%
data_set        # it's show the full dataframe and also Show the missing data with NaN
                # NaN : Missing numerical data, NaN (acronym for Not a Number)
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         226.5M
# 1               1   20801  ...       11.0         127.1M
# 2               2  190871  ...       11.0         228.1M
# 3               3  193080  ...       94.0         138.6M
# 4               4  192985  ...       13.0         196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           143K
# 18203       18203  243165  ...       12.0           113K
# 18204       18204  241638  ...       13.0           165K
# 18205       18205  246268  ...        9.0           143K
# 18206       18206  246269  ...        9.0           165K
#
# [18207 rows x 60 columns]

# %% [markdown]
# 4. Show the first 5 row from the set...

# %%
data_set.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         226.5M
# 1           1   20801  ...       11.0         127.1M
# 2           2  190871  ...       11.0         228.1M
# 3           3  193080  ...       94.0         138.6M
# 4           4  192985  ...       13.0         196.4M
#
# [5 rows x 60 columns]

# %% [markdown]
# 5. Compare the sum of all player from different nation...

# %%
sms.countplot(x='Nationality', data=data_set)
data_set['Nationality'].value_counts()
# Out:
# England          1662
# Germany          1198
# Spain            1072
# Argentina         937
# France            914
#                  ...
# Botswana            1
# New Caledonia       1
# Belize              1
# South Sudan         1
# Fiji                1
# Name: Nationality, Length: 164, dtype: int64

# %%
sms.countplot(x='Age', data=data_set, hue='Nationality')

# %%
# series is a 1-D array

footballer_name = pd.Series(["L. Messi", "Cristiano Ronaldo", "Neymar Jr"])
footballer_country = pd.Series(["Argentina", "Portugal", "Brazil"])

# %%
footballer_name       # pop up the footballer name. And it's datatype
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# 2            Neymar Jr
# dtype: object

# %%
footballer_country      # pop up the country name and it's data type
# Out:
# 0    Argentina
# 1     Portugal
# 2       Brazil
# dtype: object

# %%
# A dataframe is a 2D structure with key value

footballer_data = pd.DataFrame({"Name":footballer_name, "Country":footballer_country})
footballer_data
# Out:
#                 Name    Country
# 0           L. Messi  Argentina
# 1  Cristiano Ronaldo   Portugal
# 2          Neymar Jr     Brazil

# %%
data_set.dtypes        # will show the types of each column
# Out:
# Unnamed: 0                    int64
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall Reating               int64
# Potential                     int64
# Club                         object
# Value                        object
# Wage                         object
# Special                       int64
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Body Type                    object
# Real Face                    object
# Position                     object
# Jersey Number               float64
# Joined                       object
# Loaned From                  object
# Contract Valid Until         object
# Height                       object
# Weight                       object
# Crossing                    float64
# ...

# %%
data_set.columns      # it will show the name of the column
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Nationality', 'Overall Reating',
#        'Potential', 'Club', 'Value', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
data_set.index        # will show the index range
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
data_set.describe()     # will show the statistical analysis from the column
# Out:
#          Unnamed: 0             ID  ...  GKPositioning    GKReflexes
# count  18207.000000   18207.000000  ...   18159.000000  18159.000000
# mean    9103.000000  214298.338606  ...      16.388898     16.710887
# std     5256.052511   29965.244204  ...      17.034669     17.955119
# min        0.000000      16.000000  ...       1.000000      1.000000
# 25%     4551.500000  200315.500000  ...       8.000000      8.000000
# 50%     9103.000000  221759.000000  ...      11.000000     11.000000
# 75%    13654.500000  236529.500000  ...      14.000000     14.000000
# max    18206.000000  246620.000000  ...      90.000000     94.000000
#
# [8 rows x 44 columns]

# %%
data_set.info()         # will show the info of each missing column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Nationality               18207 non-null  object
#  5   Overall Reating           18207 non-null  int64
#  6   Potential                 18207 non-null  int64
#  7   Club                      17966 non-null  object
#  8   Value                     18207 non-null  object
#  9   Wage                      18207 non-null  object
#  10  Special                   18207 non-null  int64
#  11  Preferred Foot            18159 non-null  object
#  12  International Reputation  18159 non-null  float64
# ...

# %%
data_set.mean()         # mean function give the average of numarical column
# Out:
# Unnamed: 0                    9103.000000
# ID                          214298.338606
# Age                             25.122206
# Overall Reating                 66.238699
# Potential                       71.307299
# Special                       1597.809908
# International Reputation         1.113222
# Weak Foot                        2.947299
# Skill Moves                      2.361308
# Jersey Number                   19.546096
# Crossing                        49.734181
# Finishing                       45.550911
# HeadingAccuracy                 52.298144
# ShortPassing                    58.686712
# Volleys                         42.909026
# Dribbling                       55.371001
# Curve                           47.170824
# FKAccuracy                      42.863153
# LongPassing                     52.711933
# BallControl                     58.369459
# Acceleration                    64.614076
# SprintSpeed                     64.726967
# ...

# %%
data_set.groupby(["Club"]).mean()       # grouping data using club name & function groupby
# Out:
#                          Unnamed: 0             ID  ...  GKPositioning  GKReflexes
# Club                                                ...
#  SSV Jahn Regensburg    9405.310345  219059.413793  ...      16.103448   16.206897
# 1. FC Heidenheim 1846   9278.428571  219734.142857  ...      17.035714   16.142857
# 1. FC Kaiserslautern   11495.692308  220848.230769  ...      15.192308   15.038462
# 1. FC Köln              5241.035714  208388.714286  ...      17.857143   17.964286
# 1. FC Magdeburg         9514.115385  226487.961538  ...      15.615385   17.230769
# ...                             ...            ...  ...            ...         ...
# Zag??bie Lubin         11951.777778  211136.296296  ...      16.518519   16.814815
# Zag??bie Sosnowiec     13864.840000  219129.880000  ...      15.640000   16.520000
# Çaykur Rizespor         8332.900000  211290.833333  ...      17.866667   17.566667
# Örebro SK              13289.296296  224120.185185  ...      16.074074   15.666667
# ...

# %%
footballer_wage = pd.Series([110.5, 77, 118.5])
footballer_wage.mean()
# Out:
# 102.0

# %%
data_set["International Reputation"].sum()      # this will show the sum of International Reputation column
# Out:
# 20215.0

# %%
pd.crosstab(footballer_name, footballer_country)        # showing that which player are from which country
                                                        # showing the data also as matrix
# Out:
# col_0              Argentina  Brazil  Portugal
# row_0
# Cristiano Ronaldo          0       0         1
# L. Messi                   1       0         0
# Neymar Jr                  0       1         0

# %%
# plotting Data 

data_set["Jersey Number"].plot()

# %%
data_set["Jersey Number"].hist()        # histrogram mean how many data we have in the column("Jerser Number")

# %% [markdown]
# Data manipulation - 1-It stands for Data Manipulation Language.
# 2-It is used to add, retrieve or update the data.
# 3-It add or update the row of the table. These rows are called as tuple.
# 4-It is further classified into Procedural and Non-Procedural DML.
# 5-BASIC command present in DML are UPDATE, INSERT, MERGE etc.
# 6-While DML uses WHERE clause in its statement.

# %%
data_set['Club'] = data_set['Club'].str.lower()
data_set
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         226.5M
# 1               1   20801  ...       11.0         127.1M
# 2               2  190871  ...       11.0         228.1M
# 3               3  193080  ...       94.0         138.6M
# 4               4  192985  ...       13.0         196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           143K
# 18203       18203  243165  ...       12.0           113K
# 18204       18204  241638  ...       13.0           165K
# 18205       18205  246268  ...        9.0           143K
# 18206       18206  246269  ...        9.0           165K
#
# [18207 rows x 60 columns]

# %%
# Working with missing Data

data_missing = pd.read_csv("/content/drive/MyDrive/SP_7th_Project_2/SP.csv", encoding="ISO-8859-1")
data_missing
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         226.5M
# 1               1   20801  ...       11.0         127.1M
# 2               2  190871  ...       11.0         228.1M
# 3               3  193080  ...       94.0         138.6M
# 4               4  192985  ...       13.0         196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           143K
# 18203       18203  243165  ...       12.0           113K
# 18204       18204  241638  ...       13.0           165K
# 18205       18205  246268  ...        9.0           143K
# 18206       18206  246269  ...        9.0           165K
#
# [18207 rows x 60 columns]

# %%
# finning the missing data
data_missing['International Reputation'].fillna(data_missing['International Reputation'].mean(), inplace=True)
data_missing
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         226.5M
# 1               1   20801  ...       11.0         127.1M
# 2               2  190871  ...       11.0         228.1M
# 3               3  193080  ...       94.0         138.6M
# 4               4  192985  ...       13.0         196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           143K
# 18203       18203  243165  ...       12.0           113K
# 18204       18204  241638  ...       13.0           165K
# 18205       18205  246268  ...        9.0           143K
# 18206       18206  246269  ...        9.0           165K
#
# [18207 rows x 60 columns]

# %%
# removing missing values/cleaning empty rows

data_missing.dropna(inplace=True)
data_missing
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Nationality, Overall Reating, Potential, Club, Value, Wage, Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause]
# Index: []

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Name, Age, Nationality, Overall Reating, Potential, Club, Value, Wage, Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause]
# Index: []
